# %% [markdown]
# ## Python Intrepreter Setting Up
#
# Install a minicode to make our project use python3.8. Because of our package dependancy, our project is running on python3.8 currently. However, the mechanism does not support to change the defaulted python3.10 kernel to other python kernels.  Therefore, we need make python3.8 by ourself.
#
# The method is by installing a miniconda, and setting the python kerynel by commd.

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# --2025-03-27 00:25:43--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M  64.7MB/s    in 1.3s
#
# 2025-03-27 00:25:45 (64.7 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
#     - cryptography==2.8=py38h1ba5d50_0
#     - idna==2.8=py38_1000
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py38_1
#     - pycosat==0.6.3=py38h7b6447c_0
#     - pycparser==2.19=py_0
#     - pyopenssl==19.1.0=py38_0
#     - pysocks==1.7.1=py38_0
#     - python==3.8.1=h0371630_1
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py38_1
#     - ruamel_yaml==0.15.87=py38h7b6447c_0
#     - setuptools==45.2.0=py38_0
#     - six==1.14.0=py38_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py38_0
#     - wheel==0.34.2=py38_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py38_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py38_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py38h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py38_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py38_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py38h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py38h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py38_1000
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py38_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py38h7b6447c_0
#   pycparser          pkgs/main/noarch::pycparser-2.19-py_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py38_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py38_0
#   python             pkgs/main/linux-64::python-3.8.1-h0371630_1
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py38_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py38h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py38_0
#   six                pkgs/main/linux-64::six-1.14.0-py38_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py38_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py38_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... ^C
# Collecting package metadata (current_repodata.json): ...working... ^C
# /usr/local/bin/python: No module named ipykernel

# %% [markdown]
# ##  Installing required packages.
#
# + Protobuf is to fix a feature on google colab.
# + marllib, our main package
# + **ray[rllib], gym**, because of the kernel changed in google colab, we need installed this package explicitly.

# %%
# !/usr/local/bin/pip install protobuf==3.20.0 marllib==1.0.3 ray[rllib]==1.8 gym==0.20.0 numpy==1.22
# Out:
# Requirement already satisfied: protobuf==3.20.0 in /usr/local/lib/python3.8/site-packages (3.20.0)
# Requirement already satisfied: marllib==1.0.3 in /usr/local/lib/python3.8/site-packages (1.0.3)
# Requirement already satisfied: ray[rllib]==1.8 in /usr/local/lib/python3.8/site-packages (1.8.0)
# Requirement already satisfied: gym==0.20.0 in /usr/local/lib/python3.8/site-packages (0.20.0)
# Requirement already satisfied: numpy==1.22 in /usr/local/lib/python3.8/site-packages (1.22.0)
# Requirement already satisfied: pettingzoo[mpe]==1.12.0 in /usr/local/lib/python3.8/site-packages (from marllib==1.0.3) (1.12.0)
# Requirement already satisfied: icecream==2.1.3 in /usr/local/lib/python3.8/site-packages (from marllib==1.0.3) (2.1.3)
# Requirement already satisfied: supersuit==3.2.0 in /usr/local/lib/python3.8/site-packages (from marllib==1.0.3) (3.2.0)
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.8/site-packages (from marllib==1.0.3) (1.9.0)
# Requirement already satisfied: importlib-metadata==4.13.0 in /usr/local/lib/python3.8/site-packages (from marllib==1.0.3) (4.13.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (4.23.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (3.16.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (6.0.2)
# Requirement already satisfied: redis>=3.5.0 in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (5.2.1)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (1.70.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (25.3.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (1.1.0)
# Requirement already satisfied: requests; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (2.22.0)
# Requirement already satisfied: lz4; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (4.3.3)
# Requirement already satisfied: scipy; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (1.10.1)
# Requirement already satisfied: tensorboardX>=1.9; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (2.6.2.2)
# Requirement already satisfied: matplotlib!=3.4.3; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (3.7.5)
# Requirement already satisfied: pandas; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (2.0.3)
# Requirement already satisfied: scikit-image; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (0.21.0)
# Requirement already satisfied: dm-tree; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (0.1.8)
# Requirement already satisfied: tabulate; extra == "rllib" in /usr/local/lib/python3.8/site-packages (from ray[rllib]==1.8) (0.9.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/site-packages (from gym==0.20.0) (3.1.1)
# Collecting pyglet>=1.4.0; extra == "mpe"
#   Downloading pyglet-2.1.3-py3-none-any.whl (962 kB)
#      |████████████████████████████████| 962 kB 7.8 MB/s
# Requirement already satisfied: asttokens>=2.0.1 in /usr/local/lib/python3.8/site-packages (from icecream==2.1.3->marllib==1.0.3) (3.0.0)
# Requirement already satisfied: colorama>=0.3.9 in /usr/local/lib/python3.8/site-packages (from icecream==2.1.3->marllib==1.0.3) (0.4.6)
# Requirement already satisfied: executing>=0.3.1 in /usr/local/lib/python3.8/site-packages (from icecream==2.1.3->marllib==1.0.3) (2.2.0)
# Requirement already satisfied: pygments>=2.2.0 in /usr/local/lib/python3.8/site-packages (from icecream==2.1.3->marllib==1.0.3) (2.19.1)
# Requirement already satisfied: opencv-python~=3.4.0 in /usr/local/lib/python3.8/site-packages (from supersuit==3.2.0->marllib==1.0.3) (3.4.18.65)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/site-packages (from torch==1.9.0->marllib==1.0.3) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/site-packages (from importlib-metadata==4.13.0->marllib==1.0.3) (3.20.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[rllib]==1.8) (2023.12.1)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[rllib]==1.8) (6.4.5)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[rllib]==1.8) (0.20.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[rllib]==1.8) (0.35.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from jsonschema->ray[rllib]==1.8) (1.3.10)
# Requirement already satisfied: async-timeout>=4.0.3; python_full_version < "3.11.3" in /usr/local/lib/python3.8/site-packages (from redis>=3.5.0->ray[rllib]==1.8) (5.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/site-packages (from requests; extra == "rllib"->ray[rllib]==1.8) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/site-packages (from requests; extra == "rllib"->ray[rllib]==1.8) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests; extra == "rllib"->ray[rllib]==1.8) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests; extra == "rllib"->ray[rllib]==1.8) (2019.11.28)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/site-packages (from tensorboardX>=1.9; extra == "rllib"->ray[rllib]==1.8) (24.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]==1.8) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]==1.8) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]==1.8) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]==1.8) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]==1.8) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]==1.8) (3.1.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]==1.8) (4.56.0)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.8/site-packages (from pandas; extra == "rllib"->ray[rllib]==1.8) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/site-packages (from pandas; extra == "rllib"->ray[rllib]==1.8) (2025.2)
# Requirement already satisfied: imageio>=2.27 in /usr/local/lib/python3.8/site-packages (from scikit-image; extra == "rllib"->ray[rllib]==1.8) (2.35.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.8/site-packages (from scikit-image; extra == "rllib"->ray[rllib]==1.8) (3.1)
# Requirement already satisfied: lazy_loader>=0.2 in /usr/local/lib/python3.8/site-packages (from scikit-image; extra == "rllib"->ray[rllib]==1.8) (0.4)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.8/site-packages (from scikit-image; extra == "rllib"->ray[rllib]==1.8) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/site-packages (from scikit-image; extra == "rllib"->ray[rllib]==1.8) (1.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.4.3; extra == "rllib"->ray[rllib]==1.8) (1.14.0)
# Installing collected packages: pyglet
# Successfully installed pyglet-2.1.3

# %% [markdown]
# ## Persist sourcode to a file
#
# If we run ```import xxxx``` directly in google colab, the google colab sitll will call its default kernel.
#
# Therefore, we need to use ```usr/local/bin/python3.8```, which was installed in the previous step, to run our program by given a file.

# %%
# example_usage = """
from marllib import marl

# prepare env
env = marl.make_env(environment_name="mpe", map_name="simple_spread")

# initialize algorithm with appointed hyper-parameters
mappo = marl.algos.mappo(hyperparam_source="mpe")

# build agent model based on env + algorithms + user preference
model = marl.build_model(env, mappo, {"core_arch": "mlp", "encode_layer": "128-256"})

# start training
mappo.fit(env, model, stop={'episode_reward_mean': 2000, 'timesteps_total': 10000000}, local_mode=False, num_gpus=0,
          num_workers=1, share_policy='group', checkpoint_freq=50)
# """


# with open("marllib_script.py", "w") as file:
#     file.write(example_usage)
# Out:
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | Env_Name           | Check_Status   | Error_Log                                                                                                                           | Config_File_Location                         | Env_File_Location                   |
# +====================+================+=====================================================================================================================================+==============================================+=====================================+
# | gymnasium_mamujoco | Error          | cannot import name 'NDArray' from 'numpy.typing' (c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\numpy\typing\__init__.py) | envs/base_env/config/gymnasium_mamujoco.yaml | envs/base_env/gymnasium_mamujoco.py |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | mpe                | Ready          | Null                                                                                                                                | envs/base_env/config/mpe.yaml                | envs/base_env/mpe.py                |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | gymnasium_mpe      | Error          | cannot import name 'simple_adversary_v3' from 'pettingzoo.mpe'                                                                      | envs/base_env/config/gymnasium_mpe.yaml      | envs/base_env/gymnasium_mpe.py      |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | mamujoco           | Error          | No module named 'multiagent_mujoco'                                                                                                 | envs/base_env/config/mamujoco.yaml           | envs/base_env/mamujoco.py           |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | smac               | Error          | No module named 'smac'                                                                                                              | envs/base_env/config/smac.yaml               | envs/base_env/smac.py               |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | football           | Error          | No module named 'gfootball'                                                                                                         | envs/base_env/config/football.yaml           | envs/base_env/football.py           |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | magent             | Error          | cannot import name 'adversarial_pursuit_v3' from 'pettingzoo.magent'                                                                | envs/base_env/config/magent.yaml             | envs/base_env/magent.py             |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | rware              | Error          | No module named 'rware'                                                                                                             | envs/base_env/config/rware.yaml              | envs/base_env/rware.py              |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | lbf                | Error          | No module named 'lbforaging'                                                                                                        | envs/base_env/config/lbf.yaml                | envs/base_env/lbf.py                |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | pommerman          | Error          | No module named 'pommerman'                                                                                                         | envs/base_env/config/pommerman.yaml          | envs/base_env/pommerman.py          |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | hanabi             | Error          | No module named 'cffi'                                                                                                              | envs/base_env/config/hanabi.yaml             | envs/base_env/hanabi.py             |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | metadrive          | Error          | No module named 'metadrive'                                                                                                         | envs/base_env/config/metadrive.yaml          | envs/base_env/metadrive.py          |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | mate               | Error          | No module named 'mate'                                                                                                              | envs/base_env/config/mate.yaml               | envs/base_env/mate.py               |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | gobigger           | Error          | No module named 'gobigger'                                                                                                          | envs/base_env/config/gobigger.yaml           | envs/base_env/gobigger.py           |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | overcooked         | Error          | No module named 'overcooked_ai_py'                                                                                                  | envs/base_env/config/overcooked.yaml         | envs/base_env/overcooked.py         |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | voltage            | Error          | No module named 'pandapower'                                                                                                        | envs/base_env/config/voltage.yaml            | envs/base_env/voltage.py            |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | aircombat          | Error          | No module named 'jsbsim'                                                                                                            | envs/base_env/config/aircombat.yaml          | envs/base_env/aircombat.py          |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | hns                | Error          | No module named 'mujoco_worldgen'                                                                                                   | envs/base_env/config/hns.yaml                | envs/base_env/hns.py                |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# | sisl               | Error          | cannot import name 'multiwalker_v7' from 'pettingzoo.sisl'                                                                          | envs/base_env/config/sisl.yaml               | envs/base_env/sisl.py               |
# +--------------------+----------------+-------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------+-------------------------------------+
# c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\pettingzoo\utils\wrappers\base.py:59: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn("The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.")
# c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\pettingzoo\utils\wrappers\base.py:51: UserWarning: The `observation_spaces` dictionary is deprecated. Use the `observation_space` function instead.
#   warnings.warn("The `observation_spaces` dictionary is deprecated. Use the `observation_space` function instead.")
# c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\pettingzoo\utils\conversions.py:61: UserWarning: The `observation_spaces` dictionary is deprecated. Use the `observation_space` function instead.
#   warnings.warn("The `observation_spaces` dictionary is deprecated. Use the `observation_space` function instead.")
# c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\pettingzoo\utils\conversions.py:69: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn("The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.")
# == Status ==
# Current time: 2025-04-01 17:42:11 (running for 00:00:00.13)
# Memory usage on this node: 14.2/15.4 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using FIFO scheduling algorithm.
# Resources requested: 0/32 CPUs, 0/1 GPUs, 0.0/4.79 GiB heap, 0.0/2.4 GiB objects
# Result logdir: c:\Users\paras\Documents\ChineseCheckersRL\NewRL\MARLIB\exp_results\mappo_mlp_simple_spread
# Number of trials: 1/1 (1 PENDING)
# +--------------------------------------------+----------+-------+
# | Trial name                                 | status   | loc   |
# |--------------------------------------------+----------+-------|
# | MAPPOTrainer_mpe_simple_spread_2b456_00000 | PENDING  |       |
# +--------------------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2025-04-01 17:42:16 (running for 00:00:05.13)
# Memory usage on this node: 14.2/15.4 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using FIFO scheduling algorithm.
# Resources requested: 0/32 CPUs, 0/1 GPUs, 0.0/4.79 GiB heap, 0.0/2.4 GiB objects
# Result logdir: c:\Users\paras\Documents\ChineseCheckersRL\NewRL\MARLIB\exp_results\mappo_mlp_simple_spread
# Number of trials: 1/1 (1 PENDING)
# +--------------------------------------------+----------+-------+
# | Trial name                                 | status   | loc   |
# |--------------------------------------------+----------+-------|
# | MAPPOTrainer_mpe_simple_spread_2b456_00000 | PENDING  |       |
# +--------------------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2025-04-01 17:42:21 (running for 00:00:10.13)
# Memory usage on this node: 14.2/15.4 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using FIFO scheduling algorithm.
# Resources requested: 0/32 CPUs, 0/1 GPUs, 0.0/4.79 GiB heap, 0.0/2.4 GiB objects
# Result logdir: c:\Users\paras\Documents\ChineseCheckersRL\NewRL\MARLIB\exp_results\mappo_mlp_simple_spread
# Number of trials: 1/1 (1 PENDING)
# +--------------------------------------------+----------+-------+
# | Trial name                                 | status   | loc   |
# |--------------------------------------------+----------+-------|
# | MAPPOTrainer_mpe_simple_spread_2b456_00000 | PENDING  |       |
# +--------------------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2025-04-01 17:42:26 (running for 00:00:15.13)
# Memory usage on this node: 14.1/15.4 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using FIFO scheduling algorithm.
# Resources requested: 0/32 CPUs, 0/1 GPUs, 0.0/4.79 GiB heap, 0.0/2.4 GiB objects
# Result logdir: c:\Users\paras\Documents\ChineseCheckersRL\NewRL\MARLIB\exp_results\mappo_mlp_simple_spread
# Number of trials: 1/1 (1 PENDING)
# +--------------------------------------------+----------+-------+
# | Trial name                                 | status   | loc   |
# |--------------------------------------------+----------+-------|
# | MAPPOTrainer_mpe_simple_spread_2b456_00000 | PENDING  |       |
# +--------------------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2025-04-01 17:42:31 (running for 00:00:20.14)
# Memory usage on this node: 14.1/15.4 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using FIFO scheduling algorithm.
# Resources requested: 0/32 CPUs, 0/1 GPUs, 0.0/4.79 GiB heap, 0.0/2.4 GiB objects
# Result logdir: c:\Users\paras\Documents\ChineseCheckersRL\NewRL\MARLIB\exp_results\mappo_mlp_simple_spread
# Number of trials: 1/1 (1 PENDING)
# +--------------------------------------------+----------+-------+
# | Trial name                                 | status   | loc   |
# |--------------------------------------------+----------+-------|
# | MAPPOTrainer_mpe_simple_spread_2b456_00000 | PENDING  |       |
# +--------------------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2025-04-01 17:42:36 (running for 00:00:25.15)
# Memory usage on this node: 14.1/15.4 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using FIFO scheduling algorithm.
# Resources requested: 0/32 CPUs, 0/1 GPUs, 0.0/4.79 GiB heap, 0.0/2.4 GiB objects
# Result logdir: c:\Users\paras\Documents\ChineseCheckersRL\NewRL\MARLIB\exp_results\mappo_mlp_simple_spread
# Number of trials: 1/1 (1 PENDING)
# +--------------------------------------------+----------+-------+
# | Trial name                                 | status   | loc   |
# |--------------------------------------------+----------+-------|
# | MAPPOTrainer_mpe_simple_spread_2b456_00000 | PENDING  |       |
# +--------------------------------------------+----------+-------+
# 2025-04-01 17:42:37,833	ERROR ray_trial_executor.py:620 -- Trial MAPPOTrainer_mpe_simple_spread_2b456_00000: Unexpected error starting runner.
# Traceback (most recent call last):
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\ray_trial_executor.py", line 611, in start_trial
#     return self._start_trial(trial, checkpoint, train=train)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\ray_trial_executor.py", line 486, in _start_trial
#     runner = self._setup_remote_runner(trial)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\ray_trial_executor.py", line 328, in _setup_remote_runner
#     trainable_cls = trial.get_trainable_cls()
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\trial.py", line 700, in get_trainable_cls
#     return get_trainable_cls(self.trainable_name)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\registry.py", line 34, in get_trainable_cls
#     validate_trainable(trainable_name)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\registry.py", line 39, in validate_trainable
#     if not has_trainable(trainable_name):
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\registry.py", line 30, in has_trainable
#     return _global_registry.contains(TRAINABLE_CLASS, trainable_name)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\registry.py", line 156, in contains
#     value = _internal_kv_get(_make_key(self._prefix, category, key))
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\experimental\internal_kv.py", line 57, in _internal_kv_get
#     return ray.worker.global_worker.redis_client.hget(key, "value")
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\commands\core.py", line 4970, in hget
#     return self.execute_command("HGET", name, key, keys=[name])
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\client.py", line 559, in execute_command
#     return self._execute_command(*args, **options)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\client.py", line 567, in _execute_command
#     return conn.retry.call_with_retry(
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\retry.py", line 65, in call_with_retry
#     fail(error)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\client.py", line 571, in <lambda>
#     lambda error: self._disconnect_raise(conn, error),
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\client.py", line 555, in _disconnect_raise
#     raise error
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\retry.py", line 62, in call_with_retry
#     return do()
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\client.py", line 568, in <lambda>
#     lambda: self._send_command_parse_response(
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\client.py", line 542, in _send_command_parse_response
#     return self.parse_response(conn, command_name, **options)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\client.py", line 584, in parse_response
#     response = connection.read_response()
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\connection.py", line 592, in read_response
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\_parsers\resp2.py", line 15, in read_response
#     result = self._read_response(disable_decoding=disable_decoding)
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\_parsers\resp2.py", line 25, in _read_response
#     raw = self._buffer.readline()
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\_parsers\socket.py", line 115, in readline
#     self._read_from_socket()
#   File "c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\redis\_parsers\socket.py", line 68, in _read_from_socket
#     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
# redis.exceptions.ConnectionError: Connection closed by server.
# 2025-04-01 17:42:37,839	ERROR worker.py:472 -- print_logs: Connection closed by server.
# 2025-04-01 17:42:37,839	ERROR worker.py:1230 -- listen_error_messages_raylet: Connection closed by server.
# 2025-04-01 17:42:37,841	ERROR import_thread.py:88 -- ImportThread: Connection closed by server.
# == Status ==
# Current time: 2025-04-01 17:42:39 (running for 00:00:28.16)
# Memory usage on this node: 13.7/15.4 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/32 CPUs, 0/1 GPUs, 0.0/4.79 GiB heap, 0.0/2.4 GiB objects
# Result logdir: c:\Users\paras\Documents\ChineseCheckersRL\NewRL\MARLIB\exp_results\mappo_mlp_simple_spread
# Number of trials: 1/1 (1 ERROR)
# +--------------------------------------------+----------+-------+
# | Trial name                                 | status   | loc   |
# |--------------------------------------------+----------+-------|
# | MAPPOTrainer_mpe_simple_spread_2b456_00000 | ERROR    |       |
# +--------------------------------------------+----------+-------+
# Number of errored trials: 1
# +--------------------------------------------+--------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                 |   # failures | error file                                                                                                                                                             |
# |--------------------------------------------+--------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | MAPPOTrainer_mpe_simple_spread_2b456_00000 |            1 | c:\Users\paras\Documents\ChineseCheckersRL\NewRL\MARLIB\exp_results\mappo_mlp_simple_spread\MAPPOTrainer_mpe_simple_spread_2b456_00000_0_2025-04-01_17-42-11\error.txt |
# +--------------------------------------------+--------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ---------------------------------------------------------------------------
# GetTimeoutError                           Traceback (most recent call last)
# Cell In[1], line 14
#      11 model = marl.build_model(env, mappo, {"core_arch": "mlp", "encode_layer": "128-256"})
#      13 # start training
# ---> 14 mappo.fit(env, model, stop={'episode_reward_mean': 2000, 'timesteps_total': 10000000}, local_mode=False, num_gpus=0,
#      15           num_workers=1, share_policy='group', checkpoint_freq=50)
#      16 # """
#      17
#      18
#      19 # with open("marllib_script.py", "w") as file:
#      20 #     file.write(example_usage)
#
# File c:\users\paras\documents\marllib\marllib\marl\__init__.py:316, in _Algo.fit(self, env, model, stop, **running_params)
#     314     return run_vd(self.config_dict, env_instance, model_class, stop=stop)
#     315 elif self.algo_type == "CC":
# --> 316     return run_cc(self.config_dict, env_instance, model_class, stop=stop)
#     317 else:
#     318     raise ValueError("not supported type {}".format(self.algo_type))
#
# File c:\users\paras\documents\marllib\marllib\marl\algos\run_cc.py:194, in run_cc(exp_info, env, model, stop)
#     188 exp_info, run_config, stop_config, restore_config = restore_config_update(exp_info, run_config, stop_config)
#     190 ##################
#     191 ### run script ###
#     192 ##################
# --> 194 results = POlICY_REGISTRY[exp_info["algorithm"]](model, exp_info, run_config, env_info, stop_config,
#     195                                                  restore_config)
#     197 ray.shutdown()
#     199 return results
#
# File c:\users\paras\documents\marllib\marllib\marl\algos\scripts\mappo.py:112, in run_mappo(model, exp, run, env, stop, restore)
#     109 RUNNING_NAME = '_'.join([algorithm, arch, map_name])
#     110 model_path = restore_model(restore, exp)
# --> 112 results = tune.run(MAPPOTrainer,
#     113                    name=RUNNING_NAME,
#     114                    checkpoint_at_end=exp['checkpoint_end'],
#     115                    checkpoint_freq=exp['checkpoint_freq'],
#     116                    restore=model_path,
#     117                    stop=stop,
#     118                    config=config,
#     119                    verbose=1,
#     120                    progress_reporter=CLIReporter(),
#     121                    local_dir=available_local_dir if exp["local_dir"] == "" else exp["local_dir"])
#     123 return results
#
# File c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\tune.py:615, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, max_concurrent_trials, loggers, _remote)
#     612     _report_progress(runner, progress_reporter, done=True)
#     614 wait_for_sync()
# --> 615 runner.cleanup()
#     617 incomplete_trials = []
#     618 for trial in runner.get_trials():
#
# File c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\trial_runner.py:1354, in TrialRunner.cleanup(self)
#    1352 def cleanup(self):
#    1353     """Cleanup trials and callbacks."""
# -> 1354     self.cleanup_trials()
#    1355     self.end_experiment_callbacks()
#
# File c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\trial_runner.py:1350, in TrialRunner.cleanup_trials(self)
#    1349 def cleanup_trials(self):
# -> 1350     self._run_and_catch(self.trial_executor.cleanup)
#
# File c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\trial_runner.py:415, in TrialRunner._run_and_catch(self, func)
#     396 """Run the corresponding `func`.
#     397
#     398 First try to run the function with trials as argument. If the function
#    (...)
#     412 lead to weird behaviors.
#     413 """
#     414 try:
# --> 415     func(self.get_trials())
#     416 except AttributeError as e:
#     417     if str(e) != "'list' object has no attribute 'get_trials'":
#
# File c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\ray_trial_executor.py:1119, in RayTrialExecutor.cleanup(self, trials)
#    1117 self._trial_cleanup.cleanup(partial=False)
#    1118 self._pg_manager.reconcile_placement_groups(trials)
# -> 1119 self._pg_manager.cleanup(force=True)
#    1120 self._pg_manager.cleanup_existing_pg(block=True)
#
# File c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\tune\utils\placement_groups.py:302, in PlacementGroupManager.cleanup(self, force)
#     298 if force or (time.time() -
#     299              self._removal_delay) >= self._pgs_for_removal[pg]:
#     300     self._pgs_for_removal.pop(pg)
# --> 302     remove_placement_group(pg)
#     304     # Remove from unstaged cache
#     305     if pg in self._unstaged_pg_pgf:
#
# File c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\_private\client_mode_hook.py:150, in client_mode_wrap.<locals>.wrapper(*args, **kwargs)
#     148     ref = f.remote(*args, **kwargs)
#     149     return ray.get(ref)
# --> 150 return func(*args, **kwargs)
#
# File c:\Users\paras\anaconda3\envs\marllib\lib\site-packages\ray\util\placement_group.py:237, in remove_placement_group(placement_group)
#     234 worker = ray.worker.global_worker
#     235 worker.check_connected()
# --> 237 worker.core_worker.remove_placement_group(placement_group.id)
#
# File python\ray\_raylet.pyx:1489, in ray._raylet.CoreWorker.remove_placement_group()
#
# File python\ray\_raylet.pyx:155, in ray._raylet.check_status()
#
# GetTimeoutError: There was timeout in removing the placement group of id 33494928b6dbdd0466d22df58049d3aa. It is probably because GCS server is dead or there's a high load there.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 